# %% [markdown]
# # Data Analyst Professional Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## 📝 Task List
#
# Your written report should include written text summaries and graphics of the following:
# - Data validation:
#   - Describe validation and cleaning steps for every column in the data
# - Exploratory Analysis:
#   - Include two different graphics showing single variables only to demonstrate the characteristics of data
#   - Include at least one graphic showing two or more variables to represent the relationship between features
#   - Describe your findings
# - Definition of a metric for the business to monitor
#   - How should the business use the metric to monitor the business problem
#   - Can you estimate initial value(s) for the metric based on the current data
# - Final summary including recommendations that the business should undertake
#
# *Start writing report here..*

# %% [markdown]
# # Report: Analysis of Sales Methods for New Product Line
#
# ## Section 1: Introduction
# Pens and Printers recently launched a new line of office stationery and implemented three different sales strategies to promote it. The sales team aims to update the executive team on the effectiveness of these strategies. This report provides a comprehensive analysis of the data gathered from the sales tracking system, including validation and cleaning steps, exploratory analysis, definition of a metric for monitoring, and recommendations for future actions.
#
# The Sales team has provided with a raw dataset to perform the analysis with.

# %% [markdown]
# ## Section 2: Executive Summary of the project

# %% [markdown]
# ### Part 1. Data Validation:
#
# The **raw data file** has initially **15,000 rows and 8 columns** (numeric and categorical data). Here is a summary of the cleaning steps I took for every column in the data:
#
#     Column Name	          Details
#     week	              No change.6 unique values, from 1 to 6.
#     sales_method	      Corrected. Misspelling such as em + call & email
#                           corrected to Email + Call & Email. 3 unique methods after
#                           corrections which includes Call, Email and Email+Call, with 23
#                           values like as “em + call” and 10 values like as “email” were
#                           corrected.
#     customer_id	          No change.character variable without missing values,
#                           same as the description.
#     nb_sold	              No change.10 numeric categories without missing values from 7 to 16,
#                           same as the description
#     revenue	              Corrected. 1074 Rows with missing values were dropped.
#     years_as_customer	  Corrected. There are two records which shows records who have been
#                           customers with Pens and Printers for more than 40 years. However,
#                           Pens and Printers have been in business since 1984 which is 40
#                           years. Hence, the values for these two outliers were corrected and
#                           reset to 40 which is the maximum value.
#     nb_site_visits	      No change.Numeric values without missing values, same as the
#                           description
#     state	              No change.50 possible values without missing values, same as the
#                           description
#
# After dropping the missing values from the revenue column, there are **13,926 rows** left.
# _(All the data validation and cleaning steps are provided in details in the part 1 of section 3 after the executive summary)_
#
# ### Part 2. Exploratory analysis:
#
# **Q1: How many customers were there for each approach?**
#
# Total: 13,926 (15,000 with null values)
#
# Call: 4,781 (4,962)
#
# Email: 6,922 (7,466)
#
# Email + Call: 2,223 (2,572)
#
# There were more sales via email 6,922 (7,466) more than the other methods since it's inexpensive to use. Moreover, the Call comes in second 4,781 (4,962) while Email + Call is last with 2,223 (2,572) count
#
# **Q2: What does the spread of the revenue look like overall? And for each method?**
#
# **Overall,** the spread of the revenue looks non-normal and it's skewed to the right. It also has five peaks.
#
# **Call**: It has the smallest spread and median among the three methods. Its interquartile range (IQR) is $11
#
# **Email:** It has the second smallest spread and median among the three methods. Its interquartile range (IQR) is $17
#
# **Email + Call:** It has the largest spread and median among the three methods. Its interquartile range (IQR) is $35
#
# **Email + Call seems to be the most lucrative sale method**. However, the Email only method brought in more revenue in total since it was used more than the other methods. The Call method is by far the worst preforming method since it's expensive to implement and has the lowest revenue amounts.
#
# **Q3. Was there any difference in revenue over time for each of the methods?**
#
# Yes. The revenue for method indeed increased over time; however, the change varies among the methods
#
# Call has the smallest increase. It has means (or averages) of 35 in week 1 and 66 in week 6, a $31 increase
#
# Email has the second smallest increased. It has means of 87 in week 1, and 130 in week 6, a $43 increase
#
# Email + Call has the largest increase. For instance, its means for week 1 and week 6 are 128 and 227, respectively. That's an increase of $99
#
# **Q4: Based on the data, which method would you recommend we continue to use? Some of these methods take more time from the team so they may not be the best for us to use if the results are similar**
#
# I recommend that the company continues to use the **Email + Call method** and **Email method** since they captures the most revenue with the potential to significantly increase over time.

# %% [markdown]
# ### Part 3 : Business Metric:
#
# **Metric:** Average Weekly Revenue by Sales Method
#
# **Definition:** Total sum of revenue generated by each sales method divided by the weeks spent under each method to achieve the sales.
#
# **Business Goal:** To increase the revenue generated from sales by applying and monitoring the performance of different sales methods or approach (Email, Calls, Email+Calls)
#
# **Monitoring Approach:** Track the average weekly revenue for each sales method over time to assess effectiveness.
#
# **Initial Estimates based on current data:**
#
#            sales_method  avg_weekly_revenue
#                   Call        37927.25
#                  Email       112052.97
#           Email + Call        68042.78

# %% [markdown]
# ## Part 4. Final summary of the findings including recommendations that the business should undertake
#
# #### 1)Continue to keep working with 'Email+Calls' approach
# Although given a period of time, count of customers is less but the average size of sales is high with the minimum sale value to be much higher than the average of calls or average of emails alone. Additionally, the average weekly revenue generated out of Email+Call sales_method is almost double that of 'Calls' method.
#
#
# #### 2)Continue to keep working with 'Email' approach.
# The count of customers is maximum plus the average weekly revenue is quite high. It has much lower standard deviation as compared with 'Email+calls' approach and a comparable standard deviation with 'calls' approach. Additionally, the mean sales value is pretty competitive.
#
#
# #### 3)The business can consider discontinuing 'Calls' appraoch for sometime and see.
# Given that the 'Calls' method has a low average weekly revenue over a 6 weeks time frame. And its mean revenue size is quite small as compared with the mean revenue of the entire population, the company can give it a thought and consider to discontinue 'Calls' approach.

# %% [markdown]
# ## Section 3: Detailed data validation, cleaning and processing along with stepwise implementation

# %% [markdown]
# #### A snapshot of the dataset supplied by the sales rep (top 5 Records) and a summary of the dataset is processed as below

# %%
# import libraries
import pandas as pd # for data processing
import matplotlib.pyplot as plt # for viz
import seaborn as sns # for viz

# import data
product_sales = pd.read_csv('product_sales.csv')

# view the first five rows
product_sales.head()
# Out:
#    week  sales_method  ... nb_site_visits      state
# 0     2         Email  ...             24    Arizona
# 1     6  Email + Call  ...             28     Kansas
# 2     5          Call  ...             26  Wisconsin
# 3     4         Email  ...             25    Indiana
# 4     3         Email  ...             28   Illinois
#
# [5 rows x 8 columns]

# %%
# a summary of the data
product_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   week               15000 non-null  int64
#  1   sales_method       15000 non-null  object
#  2   customer_id        15000 non-null  object
#  3   nb_sold            15000 non-null  int64
#  4   revenue            13926 non-null  float64
#  5   years_as_customer  15000 non-null  int64
#  6   nb_site_visits     15000 non-null  int64
#  7   state              15000 non-null  object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 937.6+ KB

# %% [markdown]
# ## Part 1. Data Validation and cleaning:
#
# The data file has 15,000 rows and 8 columns (numeric and categorical data). Here is an overview of the cleaning steps I took for every column in the data:
#
#     Column Name	          Details
#     week	              No change.6 unique values, from 1 to 6.
#     sales_method	      Corrected. Misspelling such as em + call & email
#                           corrected to Email + Call & Email. 3 unique methods after
#                           corrections which includes Call, Email and Email+Call, with 23
#                           values like as “em + call” and 10 values like as “email” were
#                           corrected.
#     customer_id	          No change.character variable without missing values,
#                           same as the description.
#     nb_sold	              No change.10 numeric categories without missing values from 7 to 16,
#                           same as the description
#     revenue	              Corrected. 1074 Rows with missing values were dropped.
#     years_as_customer	  Corrected. There are two records which shows records who have been
#                           customers with Pens and Printers for more than 40 years. However,
#                           Pens and Printers have been in business since 1984 which is 40
#                           years. Hence, the values for these two outliers were corrected and
#                           reset to 40 which is the maximum value.
#     nb_site_visits	      No change.Numeric values without missing values, same as the
#                           description
#     state	              No change.50 possible values without missing values, same as the
#                           description

# %%
# a summary of the data
product_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13926 entries, 1 to 14998
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   week               13926 non-null  int64
#  1   sales_method       13926 non-null  object
#  2   customer_id        13926 non-null  object
#  3   nb_sold            13926 non-null  int64
#  4   revenue            13926 non-null  float64
#  5   years_as_customer  13926 non-null  int64
#  6   nb_site_visits     13926 non-null  int64
#  7   state              13926 non-null  object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 979.2+ KB

# %% [markdown]
# With the above summary, we can see that **the revenue column has 1,074 missing values.**
#
# Before dealing with missing values, first, let's check and correct column with str or character type.

# %%
# view unique values in sales_method & state
print(product_sales.sales_method.unique())
print(' ')
print(product_sales.state.unique())
print(' ')
# Out:
# ['Email' 'Email + Call' 'Call' 'em + call' 'email']
#
# ['Arizona' 'Kansas' 'Wisconsin' 'Indiana' 'Illinois' 'Mississippi'
#  'Georgia' 'Oklahoma' 'Massachusetts' 'Missouri' 'Texas' 'New York'
#  'Maryland' 'California' 'Tennessee' 'Pennsylvania' 'North Dakota'
#  'Florida' 'Michigan' 'North Carolina' 'Hawaii' 'Colorado' 'Louisiana'
#  'Virginia' 'New Mexico' 'Arkansas' 'Alaska' 'Oregon' 'New Hampshire'
#  'Ohio' 'New Jersey' 'Connecticut' 'Iowa' 'Montana' 'Washington'
#  'Kentucky' 'Alabama' 'Nebraska' 'South Carolina' 'Minnesota'
#  'South Dakota' 'Delaware' 'Maine' 'Utah' 'West Virginia' 'Vermont'
#  'Rhode Island' 'Nevada' 'Idaho' 'Wyoming']

# %% [markdown]
# There are no misspells in the states columns.
#
# However, **the sales_method has two misspells: em + call, email. It should be Email + Call & Email.** We will address that issue.

# %%
# correct sales_method misspilled values
product_sales.loc[product_sales.sales_method=='em + call', 'sales_method'] = 'Email + Call'
product_sales.loc[product_sales.sales_method=='email', 'sales_method'] = 'Email'

# %%
# a count of sales_method
product_sales.sales_method.value_counts()
# Out:
# Email           7466
# Call            4962
# Email + Call    2572
# Name: sales_method, dtype: int64

# %%
# the missing values of each column
product_sales.isna().sum()
# Out:
# week                    0
# sales_method            0
# customer_id             0
# nb_sold                 0
# revenue              1074
# years_as_customer       0
# nb_site_visits          0
# state                   0
# dtype: int64

# %%
# find the null values in each sales_method
counts_method = product_sales.sales_method.value_counts(dropna=False)
na_revenue = product_sales.groupby('sales_method')['revenue'].count().reindex(counts_method.index)

na_counts = pd.concat([counts_method, na_revenue], axis=1).assign(NaNs=counts_method-na_revenue)
na_counts.assign(NaNs_pct=round(na_counts.NaNs/na_counts.sales_method, 2))
# Out:
#               sales_method  revenue  NaNs  NaNs_pct
# Email                 7466     6922   544      0.07
# Call                  4962     4781   181      0.04
# Email + Call          2572     2223   349      0.14

# %% [markdown]
# Since **each sales methods** has **less than 10% null values** in the revenue column, I'll simply remove those rows. After dropping the missing values from the revenue column, **there are 13,926 rows left.**

# %%
# drop rows with missing values
product_sales = product_sales.dropna()

# %% [markdown]
# **description of the dataset overall**

# %%
# dataframe description post-corrections
product_sales.describe(include='all').fillna('')
# Out:
#             week sales_method  ... nb_site_visits       state
# count    13926.0        13926  ...        13926.0       13926
# unique                      3  ...                         50
# top                     Email  ...                 California
# freq                     6922  ...                       1739
# mean    3.078271               ...      24.947006
# std      1.65065               ...       3.491491
# min          1.0               ...           12.0
# 25%          1.0               ...           23.0
# 50%          3.0               ...           25.0
# 75%          4.0               ...           27.0
# max          6.0               ...           37.0
#
# [11 rows x 8 columns]

# %% [markdown]
# **Records with outliers in years as customers**

# %%
product_sales[product_sales['years_as_customer']>40]
# Out:
# Empty DataFrame
# Columns: [week, sales_method, customer_id, nb_sold, revenue, years_as_customer, nb_site_visits, state]
# Index: []

# %% [markdown]
# There are two records which shows records who have been customers with Pens and Printers for more than 40 years. However, Pens and Printers have been in business since 1984 which is 40 years. Hence, the values for these two outliers were set to 40 which is the maximum possible value.

# %%
product_sales.loc[product_sales['years_as_customer']>40,'years_as_customer']=40

# %%
product_sales[product_sales['years_as_customer']>40].count()
# Out:
# week                 0
# sales_method         0
# customer_id          0
# nb_sold              0
# revenue              0
# years_as_customer    0
# nb_site_visits       0
# state                0
# dtype: int64

# %% [markdown]
# **Number of unique values in each column of the clean dataset**

# %%
#Number of unique values in each column
product_sales.nunique()
# Out:
# week                     6
# sales_method             3
# customer_id          13926
# nb_sold                 10
# revenue               6743
# years_as_customer       42
# nb_site_visits          26
# state                   50
# dtype: int64

# %% [markdown]
# **total observations of each sales method**

# %%
# the total observations of each sales method
product_sales.sales_method.value_counts()
# Out:
# Email           6922
# Call            4781
# Email + Call    2223
# Name: sales_method, dtype: int64

# %% [markdown]
# ## Part 2. Exploratory analysis:

# %% [markdown]
# ### 1: Analysis to find-  How many customers were there for each approach?

# %%
product_sales.sales_method.value_counts()
# Out:
# Email           6922
# Call            4781
# Email + Call    2223
# Name: sales_method, dtype: int64

# %% [markdown]
# In **graph 1**, there are more number of records for Email sales method.

# %%
# plot count of sales_method
product_sales.sales_method.value_counts().plot.barh().set_title('Graph 1: Sales Method Counts')
plt.xlabel('Counts')
plt.savefig('Graph_1.png', bbox_inches='tight');

# %% [markdown]
# In **graph 2**, most products sold are bought together in groups between 8 and 12 products in each group. For example, most customers bought around 10 products.

# %%
# plot frequency of number products sold
ax = product_sales.nb_sold.plot.hist()
ax.set_title('Graph 2: Frequency of New Porducts Sold')
ax.set_xlabel('New Porducts')
plt.savefig('Graph 2: Frequency of New Porducts Sold.png');

# %% [markdown]
# The company is succeeding at attracting new customers. In **graph 3,** new customers are mostly new to the company.

# %%
# plot count of years_as_customer
ax = product_sales.years_as_customer.value_counts().plot.bar(figsize=(10,5))
ax.set_title('Graph 3: Most company customers are new customers')
ax.set_xlabel('Years as customers')
plt.savefig('Graph 3: Most company customers are new customers.png');

# %% [markdown]
# In **graph 4**, the sales were the highest the first week but the lowest the sixth week.

# %%
# plot count of weeks since product was launched
ax = product_sales.week.value_counts().reindex([1,2,3,4,5,6])[::-1].plot.barh()
ax.set_title('Graph 4: Sales in Weeks since product was launched')
ax.set_ylabel('Weeks')
plt.savefig('Graph 4: Sales in Weeks since product was launched.png');

# %% [markdown]
# In **graph 5**, there is a positive correlation between website visits and products sold. The more visits, the more products sold.

# %%
# plot a scatter plot with regression line for website visits and products sold
ax = sns.lmplot(data=product_sales, x='nb_site_visits', y='nb_sold')
plt.title('Graph 5: The more website visit, the more products bought by customers')
plt.savefig('Graph 5: The more website visit, the more products bought by customers.png');

# %% [markdown]
# ### 2: Analysis to find - What does the spread of the revenue look like overall? And for each method?

# %% [markdown]
# **Graph 6** shows the a univariate (one variable) distribution using kernel density estimation. Probability of getting a sale with smaller revenue is far greater than a sale with a larger revenue.

# %%
# plot the density of revenue
ax = sns.kdeplot(data=product_sales, x='revenue', alpha=.5, linewidth=0, fill=True)
plt.title('Graph 6: The density of revenue overall')
plt.savefig('Graph 6: The density of revenue overall.png')

# %% [markdown]
# In **graph 7,** we see the revenue distribution in the form of a histogram for the overall as well as it highlights the distribution for each sale method

# %%
# plot the density of revenue
ax = sns.histplot(data=product_sales, x='revenue', hue='sales_method', 
                 fill=True, common_norm=True, palette="tab10", alpha=.5, linewidth=0, kde=True)
plt.title('Graph 7: The density of revenue in each sales method')
plt.savefig('Graph 7: The density of revenue in each sales method.png')

# %% [markdown]
# **Graph 8** has two plot about revenue and sales methods. Each tells a different story. For example, **the Email + Call** brings **more money on average then the other methods.** It's median was the highest. However, the Email method overall brought more revenue than the other methods since it was used the most.

# %%
# plot two plots together (boxplot & count) for revenue and sales_methods
order = ['Email + Call', 'Call', 'Email']

fig, ax = plt.subplots(1, 2, figsize=(10,5))
sns.boxplot(data=product_sales, x='sales_method', y='revenue', ax=ax[0], order=order)

revenue_sum = product_sales.groupby('sales_method')['revenue'].sum().to_frame()
sns.barplot(x=revenue_sum.index, y=revenue_sum.revenue, ax=ax[1], order=order)

fig.suptitle('Graph 8: The sales methods and revenue')
ax[0].set_title('Boxplot')
ax[1].set_title('Sum of revenue')
ax[1].set_ylabel('')
plt.savefig('Graph 6: The sales methods and revenue.png');

# %%
# the IQR of each method's revenue
from scipy.stats import iqr

call = product_sales.loc[product_sales.sales_method=='Call', 'revenue']
email = product_sales.loc[product_sales.sales_method=='Email', 'revenue']
email_call = product_sales.loc[product_sales.sales_method=='Email + Call', 'revenue']

print('Call IQR: ', iqr(call))
print('Email IQR: ', iqr(email))
print('Email + Call IQR: ', iqr(email_call))
# Out:
# Call IQR:  11.21
# Email IQR:  17.290000000000006
# Email + Call IQR:  35.33500000000001

# %% [markdown]
# ### 3. Analysis to find- Was there any difference in revenue over time for each of the methods?

# %% [markdown]
# Are the **weeks of sales** matter? **Yes**. Each week, the company is increasing it product sales revenue **(graph 9)**

# %%
# multi-plot of revenue density per week
g = sns.FacetGrid(product_sales, col="week", height=2.5, col_wrap=3)
g.map(sns.kdeplot, "revenue")
plt.savefig('Graph 9: multi-plot of revenue density per week.png');

# %% [markdown]
# In **graph 10,** the **Email + Call** sale method is notably getting **larger revenue each week.**

# %%
# multi-plot of revenue density in each sales method week by each week
g = sns.FacetGrid(product_sales, col="week", hue='sales_method', height=2.5, col_wrap=3)
g.map(sns.kdeplot, "revenue"),
plt.legend()
plt.savefig('Graph 10: multi-plot of revenue density per week.png');

# %% [markdown]
# A different representation of the the above graph **(graph 11).**

# %%
# plot of revenue in each sales method in each week
sns.barplot(
    data=product_sales, x="sales_method", y="revenue", hue="week", palette="rocket")

plt.title('Graph 11: The revenue of all sales methods increased each week')
plt.savefig('Graph 11: The revenue of all sales methods increased each week.png')

# %% [markdown]
# In **graph 12**, even when the number of new products is the same, **Email + Call** has more revenue. It might indicate that this method **is selling new products with higher prices.**

# %%
# a regression plot of revenue in each sales method by new products sold
sns.lmplot(
    data=product_sales, x="nb_sold", y="revenue", hue="sales_method")

plt.title('Graph 12: The revenue of all sales methods increased \n unequally as more products sold')
plt.savefig('Graph 12: The revenue of all sales methods increased but unequally.png')

# %%
# a regression plot of revenue in each sales method by new products sold
sns.lmplot(data=product_sales, x="week", y="revenue", hue="sales_method")

plt.title('Graph 13: The revenue of all sales methods increase \n each additional week')
plt.savefig('Graph 13: The revenue of all sales methods increase each additional week.png')

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=product_sales, x='week', y='revenue', hue='sales_method', marker='o')

# Set the labels and title for the plot
plt.xlabel('Week')
plt.ylabel('Revenue')
plt.title('Revenue Over Time(Weeks) for each sales method')

# Show the plot
plt.show()

# %% [markdown]
# The below table is a pivot table of the means and medians of revenue of each sales method per week.

# %%
# the mean and medians of the methods' revenue per week 
product_sales.groupby(['week', 'sales_method'])['revenue'].agg(['mean', 'median']).unstack().style.background_gradient()
# Out:
# <style type="text/css">
# #T_713df_row0_col0, #T_713df_row0_col1, #T_713df_row0_col2, #T_713df_row0_col3, #T_713df_row0_col4, #T_713df_row0_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_713df_row1_col0, #T_713df_row1_col3 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_713df_row1_col1, #T_713df_row1_col4 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_713df_row1_col2 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_713df_row1_col5 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_713df_row2_col0 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_713df_row2_col1 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_713df_row2_col2, #T_713df_row2_col5 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_713df_row2_col3 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_713df_row2_col4 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# ...

# %% [markdown]
# ## Part 3. Definition of Business Metric for the business to monitor and track the success of Different Sales Methods
#
# #### Metric:
# Average Weekly Revenue by Sales Method
#
# #### Definition:
# Total sum of revenue generated by each sales method divided by the weeks spent under each method to achieve the sales.
#
# #### Business Goal:
# To increase the revenue generated from sales by applying and monitoring the performance of different sales methods or approach (Email, Calls, Email+Calls)
#
# #### Monitoring Approach:
# Track the average weekly revenue for each sales method over time to assess effectiveness.
#
# #### Summary of the current data:
#
#        sales_method    revenue     week  avg_weekly_revenue
#            Call       227563.49     6        37927.25
#            Email      672317.83     6       112052.97
#        Email + Call   408256.69     6        68042.78
#
# #### Initial Estimates based on current data:
#
#            sales_method  avg_weekly_revenue
#                   Call        37927.25
#                  Email       112052.97
#           Email + Call        68042.78

# %%
metric_df= product_sales.groupby('sales_method').agg({'revenue':'sum','week':'max'}).reset_index()
metric_df['avg_weekly_revenue']=metric_df['revenue']/metric_df['week']
print(metric_df)
# Out:
#    sales_method    revenue  week  avg_weekly_revenue
# 0          Call  227563.49     6        37927.248333
# 1         Email  672317.83     6       112052.971667
# 2  Email + Call  408256.69     6        68042.781667

# %%
print(metric_df[['sales_method','avg_weekly_revenue']])
# Out:
#    sales_method  avg_weekly_revenue
# 0          Call        37927.248333
# 1         Email       112052.971667
# 2  Email + Call        68042.781667

# %% [markdown]
# #### Part 4: Recommendations are provided along in the section of executive summary

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam report and record your presentation
